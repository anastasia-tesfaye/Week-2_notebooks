# %%
install.packages("devtools")
devtools::install_github("sfsheath/cawd")
install.packages("sp")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
# ...
# from URL https://api.github.com/repos/sfsheath/cawd/zipball/master
# Installing cawd
# '/usr/lib/R/bin/R' --no-site-file --no-environ --no-save --no-restore --quiet  \
#   CMD INSTALL '/tmp/RtmpG7jann/devtools195da68495/sfsheath-cawd-928f175'  \
#   --library='/srv/rlibs' --install-tests
#
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
library("sp")
library("cawd")
par(mai=c(0,0,0,0))
plot(awmc.roman.empire.200.sp)
# Out:
# plot without title

# %%
data()

# %%
library("sp")
library("cawd")
par(mai=c(0,0,0,0))
plot(ramphs.sp)
# Out:
# plot without title

# %%
library("sp")
library("datasets")
par(mai=c(0,0,0,0))
plot(Orange)
# Out:
# plot without title

# %% [markdown]
# The first two images are of datasets that are using the basic instructions for practice data visualization using the given possible sets. The third is a failed visualization. I experimented with the library (given that data() had returned more libraries than just cawd) just to see what other data sets I could visualize or if it would even work. I was able to access the other data set with the modified library name, but the data inside doesnt seem to work well with the type of graph I indicated.

# %%
library("sp")
library("datasets")
par(mai=c(0,0))
plot(Orange)
# Out:
# Error in par(mai = c(0, 0)): graphical parameter "mai" has the wrong length
# Traceback:
#
# 1. par(mai = c(0, 0))

# %% [markdown]
# I was curious if mai had any relations to the axes, it may but resulted in an error this time. Unclear if this is related to the dataset or it's job is something else.

# %%
library("sp")
library("datasets")
par(mai=c(0,0,0))
plot(Orange)
# Out:
# Error in par(mai = c(0, 0, 0)): graphical parameter "mai" has the wrong length
# Traceback:
#
# 1. par(mai = c(0, 0, 0))

# %%
data()

# %%
library("sp")
library("datasets")
par(mai=c(0,0))
plot(HairEyeColor)
# Out:
# Error in par(mai = c(0, 0)): graphical parameter "mai" has the wrong length
# Traceback:
#
# 1. par(mai = c(0, 0))

# %%
library("sp")
library("datasets")
par(mai=c(0,0,0,0))
plot(HairEyeColor)
# Out:
# Plot with title “HairEyeColor”

# %% [markdown]
# The number of variations, measurements, etc affect whether or not this command works.

# %%
par(mai=c(0,0,0,0))
plot(HairEyeColor)
# Out:
# Plot with title “HairEyeColor”

# %%
par(mai=c(0,0,0,0))
plot(ramphs.sp)
# Out:
# plot without title

# %% [markdown]
# Dicovered that the library names are unnecessary in order to pull up the datasets after the initial time!
